# %%
import pandas as pd
import Quandl
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-c8f26a33a0ae> in <module>()
#       1 import pandas as pd
# ----> 2 import Quandl
#
# ImportError: No module named Quandl
