# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def decorateGraph():
    plt.xlabel("x-values")
    plt.ylabel("y-values")
    plt.title("Interesting graph")
    plt.legend()
# Out:
# /home/arko/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
days= [1,2,3,4,5]

sleeping= [7,8,6,11,7]
eating= [2,3,4,3,2]
working= [7,8,7,2,2]
playing= [8,5,7,8,13]

plt.stackplot(days, sleeping, eating, working, playing, colors= ['m','c','r','b'])
decorateGraph()
# Out:
# /home/arko/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
plt.plot([],[], color= 'm', label= 'sleeping', linewidth= 5)
plt.plot([],[], color= 'c', label= 'eating', linewidth= 5)
plt.plot([],[], color= 'r', label= 'working', linewidth= 5)
plt.plot([],[], color= 'b', label= 'playing', linewidth= 5)
plt.stackplot(days, sleeping, eating, working, playing, colors= ['m','c','r','b'])

decorateGraph()

# %%
slices= [7,2,2,13]
activities= ['sleeping', 'eating', 'working', 'playing']
plt.pie(slices, labels= activities, colors= ['m','c','r','b'], startangle= 90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f4057bf7550>,
# ...
#   <matplotlib.text.Text at 0x7f4057bd08d0>])

# %%
plt.pie(slices, labels= activities, colors= ['m','c','r','b'], startangle= 90, shadow= True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f40577c2490>,
# ...
#   <matplotlib.text.Text at 0x7f40578f4b90>])

# %%
plt.pie(slices, labels= activities, colors= ['m','c','r','b'], startangle= 90, explode= (0,0.1,0,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x7f405743e150>,
# ...
#   <matplotlib.text.Text at 0x7f40573d54d0>])

# %%
plt.pie(slices, 
        labels= activities, 
        colors= ['m','c','r','b'], 
        startangle= 90, 
        shadow= True,
        explode= (0,0.1,0,0), 
        autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f40572edd50>,
# ...
#   <matplotlib.text.Text at 0x7f40572aa5d0>])
