# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style= 'whitegrid', color_codes= True)
np.random.seed(sum(map(ord, "categorical")))

# %%
titanic= sns.load_dataset('titanic')
tips= sns.load_dataset('tips')
iris= sns.load_dataset('iris')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who adult_male deck  embark_town alive  alone
# 0    man       True  NaN  Southampton    no  False
# 1  woman      False    C    Cherbourg   yes  False
# 2  woman      False  NaN  Southampton   yes   True
# 3  woman      False    C  Southampton   yes  False
# 4    man       True  NaN  Southampton    no   True

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.stripplot('total_bill', 'day', data= tips)

# %%
sns.stripplot('day', 'total_bill', data= tips)

# %%
sns.stripplot('day', 'total_bill', data= tips, jitter= True)

# %%
sns.swarmplot('day', 'total_bill', data= tips)

# %%
sns.swarmplot('day', 'total_bill', data= tips, hue= 'sex')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 6.8 KB

# %%
sns.swarmplot('size', 'total_bill', data= tips)

# %%
sns.swarmplot('total_bill', 'day', data= tips, hue= 'time')

# %%
sns.boxplot('day', 'total_bill', data= tips)

# %%
sns.boxplot('day', 'total_bill', data= tips, hue= 'time')

# %%
sns.violinplot('day', 'total_bill', data= tips, hue= 'time')

# %%
sns.violinplot('day', 'total_bill', data= tips, hue= 'sex')

# %%
sns.violinplot('day', 'total_bill', data= tips, hue= 'sex', split= True)

# %%
sns.violinplot('day', 'total_bill', data= tips, hue= 'sex', split= True, inner= 'stick', palette= 'Set3')

# %%
sns.violinplot('day', 'total_bill', data=tips, inner=None, palette= 'Set1')
sns.swarmplot('day', 'total_bill', data=tips, color='w', alpha=.5)

# %%
sns.barplot('class', 'survived', hue= 'sex', data= titanic)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who adult_male deck  embark_town alive  alone
# 0    man       True  NaN  Southampton    no  False
# 1  woman      False    C    Cherbourg   yes  False
# 2  woman      False  NaN  Southampton   yes   True
# 3  woman      False    C  Southampton   yes  False
# 4    man       True  NaN  Southampton    no   True

# %%
sns.countplot('deck', data= titanic)

# %%
sns.countplot('class', data= titanic)

# %%
sns.countplot('embark_town', data= titanic)

# %%
sns.countplot('deck', hue= 'class', data= titanic)

# %%
sns.countplot(y= 'deck', hue= 'class', data= titanic)

# %%
sns.pointplot('sex', 'survived', hue= 'class', data= titanic)

# %%
sns.pointplot('deck', 'survived', hue= 'sex', data= titanic)
